# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
gaiadr3 = pd.read_csv('./Trumpler 5.csv')
lit = pd.read_csv('./Trumpler 5_literature.csv')

# %%
gaiadr3.head()
# Out:
#            solution_id                   designation            source_id  \
# 0  1636148068921376768  Gaia DR3 3351836011589101056  3351836011589101056
# 1  1636148068921376768  Gaia DR3 3351836011589115776  3351836011589115776
# 2  1636148068921376768  Gaia DR3 3351836114668337024  3351836114668337024
# 3  1636148068921376768  Gaia DR3 3351836114669036160  3351836114669036160
# 4  1636148068921376768  Gaia DR3 3351836183387786240  3351836183387786240
#
#    random_index  ref_epoch         ra  ra_error        dec  dec_error  \
# 0     279717905     2016.0  99.710953  0.151205  11.252330   0.152256
# 1     543080888     2016.0  99.715514  0.159407  11.259167   0.169878
# 2     291203320     2016.0  99.730103  0.227921  11.261772   0.236038
# 3    1425362832     2016.0  99.727211  0.342979  11.263236   0.359738
# 4    1494442891     2016.0  99.686287  0.248594  11.248990   0.249006
#
#    parallax  ...       A_i       A_z       A_y       A_J       A_H       A_K  \
# ...

# %%
plt.figure(figsize=(10, 8))
plt.scatter(gaiadr3.ra, gaiadr3.dec, s=2.5, color='tomato', label='Gaia DR3$\pm2^\circ$')
plt.scatter(lit.ra, lit.dec, marker='D', color='black', label='Literature')
plt.gca().set_xlabel('$\\alpha$ [deg]', fontsize=16)
plt.gca().set_ylabel('$\delta$ [deg]', fontsize=16)
plt.legend();

# %%
a = np.loadtxt('Trumpler 5_isochrone.dat', usecols=(28, 29, 30))

# %%
plt.plot(a[:-1, 1]-a[:-1, 2], a[:-1, 0])
plt.gca().invert_yaxis();
