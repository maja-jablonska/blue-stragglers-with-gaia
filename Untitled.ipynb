# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
d = pd.read_csv('/home/maya/Downloads/1657181194648O-result.csv')

# %%
d.head()
# Out:
#            solution_id                   designation            source_id  \
# 0  1636148068921376768  Gaia DR3 2300138708529315712  2300138708529315712
# 1  1636148068921376768  Gaia DR3 2300141663466822400  2300141663466822400
# 2  1636148068921376768  Gaia DR3 2300141667762951680  2300141667762951680
# 3  1636148068921376768  Gaia DR3 2300141938344743680  2300141938344743680
# 4  1636148068921376768  Gaia DR3 2300142007064237952  2300142007064237952
#
#    random_index  ref_epoch          ra  ra_error        dec  dec_error  \
# 0     662381376     2016.0  359.985190  0.082591  85.152716   0.076308
# 1    1219913963     2016.0  359.864403  0.184853  85.159847   0.178241
# 2     675368024     2016.0  359.912261  2.632776  85.157557   1.803413
# 3     905723877     2016.0  359.893132  0.126966  85.175524   0.126572
# 4     365479039     2016.0  359.844342  0.623943  85.192913   0.546537
#
#    parallax  ...  azero_gspphot  azero_gspphot_lower  azero_gspphot_upper  \
# ...

# %%
plt.figure(figsize=(20, 10))
plt.scatter(d.ra, d.dec)

# %%
d[d['ra']<100].ra.max()
# Out:
# 23.943850976543523

# %%
plt.figure(figsize=(20, 10))
plt.hist(d.parallax, bins=100);
